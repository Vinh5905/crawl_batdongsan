# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('./data.csv')

# %%
data.head(5)
# Out:
#                   nameSeller                 emailSeller   userId  count  \
# 0         Hùng Sơn Hifriendz   nguyenhungsonne@gmail.com  3051805     20
# 1         Hùng Sơn Hifriendz   nguyenhungsonne@gmail.com  3051805     20
# 2  Nghĩa - Dylan Unite Group  trantatnghia2105@gmail.com  2541791     20
# 3  Nghĩa - Dylan Unite Group  trantatnghia2105@gmail.com  2541791     20
# 4                       Hưng       infosunny10@gmail.com   225063     20
#
#    productId    price     pricePerM2  categoryId cityCode  districtId  ...  \
# 0   40577160  3800000   95000.000000          57       SG          69  ...
# 1   40984555  7600000  138181.818182          57       SG          69  ...
# 2   40704688  6000000  171428.571429          57       SG          66  ...
# 3   39875251  6500000  162500.000000          57       SG          66  ...
# 4   36192033  5600000  215384.615385          57       HN           7  ...
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 703 entries, 0 to 702
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   nameSeller      703 non-null    object
#  1   emailSeller     551 non-null    object
#  2   userId          703 non-null    int64
#  3   count           703 non-null    int64
#  4   productId       703 non-null    int64
#  5   price           703 non-null    int64
#  6   pricePerM2      703 non-null    float64
#  7   categoryId      703 non-null    int64
#  8   cityCode        703 non-null    object
#  9   districtId      703 non-null    int64
#  10  streetId        703 non-null    int64
#  11  wardId          703 non-null    int64
#  12  projectId       703 non-null    int64
#  13  productType     703 non-null    int64
#  14  area            703 non-null    float64
#  15  latitude        703 non-null    float64
#  16  longitude       703 non-null    float64
# ...

# %% [markdown]
# <h3>Giải thích các giá trị</h3>
#
# - nameSeller : Người cho thuê
# - emailSeller : Email của người cho thuê
# - userID : Mã id của người cho thuê
# - count :
# - productId : ID của phòng trọ cho thuê
# - price : Giá thuê
# - pricePerM2 : Giá thuê / m2
# - categoryId :
# - cityCode :
# - districtId :
# - streetId :
# - wardId :
# - productType :
# - area :
# - latitude :
# - longitude :
# - Link :
# - Title :
# - Address :
# - Verified :
# - Images :
# - Mức giá :
# - Mức giá ext :
# - Diện tích :
# - Diện tích ext :
# - Phòng ngủ :
# - Phòng ngủ ext :
# - Detail : Thông tin bổ sung
# - Số phòng ngủ :
# - Số toilet :
# - Nội thất :
# - Ngày đăng :
# - Ngày hết hạn :
# - Loại tin :
# - Mã tin :
# - Hướng ban công :
# - Số tầng :
# - Mặt tiền :
# - Đường vào :
# - Pháp lý :
# - Hướng nhà :
